# %%
from genere_rapport.notebook_to_rapport import notebook_to_html_plotly

# %%
path_notebook = "viz_hospital.ipynb"

direction_sortie = "rapport_hospital.html"

notebook_to_html_plotly(path_notebook, direction_sortie)
# Out:
# '/Users/fabynuur/Desktop/DataVis1/DataViz-hospital/rapport_hospital.html'
